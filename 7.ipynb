# %%
#step size is optional by defaultit one
my_sub (0:10)
# Out:
#   File "/tmp/ipython-input-1552134050.py", line 2
#     my_sub (0:10)
#              ^
# SyntaxError: invalid syntax

# %%
#slicing
my_sub = "machine learning"
my_sub[7:15]
# Out:
# ' learnin'

# %%
#slincing
my_sub = "sahil"
my_sub[0:6]
# Out:
# 'sahil'

# %%
from os import name
#concatenate-- string is concatenate
first_name = "sahil"
last_name = "r"
ful_name = first_name + last_name
print(full_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2036101777.py in <cell line: 0>()
#       4 last_name = "r"
#       5 ful_name = first_name + last_name
# ----> 6 print(full_name)
#
# NameError: name 'full_name' is not defined

# %%
#concatenate-- strinc is concatenated
first_name = "sahil"
last_name = "r"
full_name = first_name + last_name
print(full_name)
# Out:
# sahilr
# sahilr
