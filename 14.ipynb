# %%
#list are collection of iteams seperateed by comas and closed by square brackets.
my_sub =[78,62,56,]
print(type(my_sub))
# Out:
# <class 'list'>

# %%
my_list =[12,32]
print(len(my_list))
# Out:
# 2

# %%
my_list =[12,43,65,89,00]
print(my_list[3])
print(my_list[1])
print(my_list[0])
# Out:
# 89
# 43
# 12

# %%
my_list=[12,43,65,89,00]
print(my_list[-2])
print(my_list[-1])
print(my_list[-3])
# Out:
# 89
# 0
# 65

# %%
my_list = [2,4,5,7,9,0]
my_list[2]=3
print(my_list)
# Out:
# [2, 4, 3, 7, 9, 0]

# %%
my_list = [2,4,5,7,9,0]
(my_list[1:3])
# Out:
# [4, 5]

# %%
my_list[:5]
# Out:
# [2, 4, 5, 7, 9]

# %%
my_list [: :-1]
# Out:
# [0, 9, 7, 5, 4, 2]

# %%
print(my_list)
# Out:
# [2, 4, 5, 7, 9, 0]

# %%
#function in list
#min()--this function find the minimum number of item in list
my_list = [2,4,5,7,9,]
print(min(my_list))
# Out:
# 2

# %%
my_list = [1,3,4,6,9,0]
print(sorted(my_list,reverse=True))
# Out:
# [9, 6, 4, 3, 1, 0]

# %%
#sort()--arranging list in increasing or decreasing order
my_list = [1,6,8,7]
my_list.sort()
print(my_list)
# Out:
# [1, 6, 7, 8]

# %%
my_list =[1,3,4,6,9,0]
my_list.append(23)
print(my_list)
# Out:
# [1, 3, 4, 6, 9, 0, 23]
